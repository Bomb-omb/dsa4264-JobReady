# %%
import pandas as pd
import numpy as np

# %%
mcf= pd.read_csv("data/mcf_clean_data.csv")
len(mcf)
# Out:
# 22719

# %%
mcf.head()
# Out:
#                                uuid  \
# 0  0f754b51f0e412570c88adf9ecc0e872
# 1  705309ff2a8d68b7ee215b6e2fc420ab
# 2  4a68226fc8b1d6f39bcf78451f7bc198
# 3  4726f24811127db6967fd1c07ec7ae77
# 4  301389565abb7d8ddd32efebb58776cf
#
#                                      raw_title  \
# 0  Assistant Manager, Corporate Communications
# 1              Manager (Facilities Management)
# 2                          Sales Administrator
# 3       Assistant Field Engineer(Construction)
# 4                  Electronic Keyboard Teacher
#
#                                          title  \
# 0  Assistant Manager, Corporate Communications
# 1              Manager (Facilities Management)
# 2                          Sales Administrator
# 3       Assistant Field Engineer(Construction)
# 4                  Electronic Keyboard Teacher
#
#                                      raw_description  \
# 0  <p><strong>Job Summary: </strong></p><p>This r...
# 1  <p><strong >Role Overview</strong></p><p>We ar...
# ...

# %%
mcf.dtypes
# Out:
# uuid                      object
# raw_title                 object
# title                     object
# raw_description           object
# description               object
# minimumYearsExperience     int64
# skills                    object
# categories                object
# employmentTypes           object
# positionLevels            object
# dtype: object

# %%
mcf["positionLevels"].unique()
# Out:
# array(['["Junior Executive"]', '["Manager"]', '["Executive"]',
#        '["Fresh/entry level"]', '["Non-executive"]', '["Professional"]',
#        '["Senior Executive"]', '["Senior Management"]',
#        '["Middle Management"]', '["Manager", "Executive"]',
#        '["Middle Management", "Manager"]',
#        '["Non-executive", "Fresh/entry level"]',
#        '["Executive", "Fresh/entry level"]',
#        '["Senior Management", "Manager"]'], dtype=object)

# %% [markdown]
# ### Filter to Entry level only

# %%
mcf_filtered = mcf[
    mcf["positionLevels"].str.contains("Fresh/entry level", na=False)
]

mcf_filtered.head()
# Out:
#                                 uuid  \
# 3   4726f24811127db6967fd1c07ec7ae77
# 5   dd32ada5c76ba97526adf85326a58793
# 11  91dc337d5944663301fb1b60519c5e46
# 16  1f296d6da33fc7ce8d408b4cdccc5f8e
# 22  9f7f01d8e8e081eac94f0c3aca328ac7
#
#                                             raw_title  \
# 3              Assistant Field Engineer(Construction)
# 5                                       F&B Executive
# 11    Outreach Operations and Data Analysis Executive
# 16                            Installation Technician
# 22  Junior Marketing Crew - Entry Level/Training P...
#
#                                                 title  \
# 3              Assistant Field Engineer(Construction)
# 5                                       F&B Executive
# 11    Outreach Operations and Data Analysis Executive
# 16                            Installation Technician
# 22  Junior Marketing Crew - Entry Level/Training P...
#
#                                       raw_description  \
# ...

# %% [markdown]
# ### Number of rows and column type

# %%
len(mcf_filtered)
# Out:
# 4156

# %%
mcf_filtered["positionLevels"].unique()
# Out:
# array(['["Fresh/entry level"]', '["Non-executive", "Fresh/entry level"]',
#        '["Executive", "Fresh/entry level"]'], dtype=object)

# %% [markdown]
# ### Save dataset

# %%
mcf_filtered.to_csv("data/mcf_entrylevel.csv", index=False)
