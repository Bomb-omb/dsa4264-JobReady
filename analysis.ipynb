# %%
import pandas as pd
import json
import os

# %%
file_path = os.path.join(os.getcwd(), 'data', 'raw', 'nusmods', '2025-2026_moduleList.json')

df = pd.read_json(file_path)
print(df.head())
# Out:
#   moduleCode                                title semesters
# 0    ABM5001            Leadership in Biomedicine       [2]
# 1    ABM5002  Advanced Biostatistics for Research       [2]
# 2    ABM5003   Biomedical Innovation & Enterprise       [1]
# 3    ABM5004                     Capstone Project    [1, 2]
# 4    ABM5101                   Applied Immunology       [1]
